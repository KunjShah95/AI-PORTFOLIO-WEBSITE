# %% [markdown]
# <a href="https://colab.research.google.com/github/KunjShah95/AI-PORTFOLIO-WEBSITE/blob/main/Question_Answering_System_for_PDFs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install transformers PyPDF2 torch

# %%
from transformers import pipeline
from PyPDF2 import PdfReader

# Load the QA model
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2")

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    reader = PdfReader(pdf_path)
    text = ""
    for page in reader.pages:
        text += page.extract_text()
    return text

# Function to answer questions
def answer_question(question, context):
    result = qa_pipeline({"question": question, "context": context})
    return result["answer"]

# Interactive user input
if __name__ == "__main__":
    # Step 1: Get PDF file path
    pdf_path = input("Enter the path to the PDF file: ").strip()
    try:
        pdf_text = extract_text_from_pdf(pdf_path)
        print("PDF text successfully extracted!")
    except Exception as e:
        print(f"Error reading PDF: {e}")
        exit()

    # Step 2: Ask questions interactively
    while True:
        question = input("\nEnter your question (or type 'exit' to quit): ").strip()
        if question.lower() == "exit":
            print("Exiting...")
            break
        answer = answer_question(question, pdf_text)
        print(f"Answer: {answer}")
# Out:
# Device set to use cpu
# PDF text successfully extracted!
# Answer: March 14, 1879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5d56e85a2eb3> in <cell line: 0>()
#      35             print("Exiting...")
#      36             break
# ---> 37         answer = answer_question(question, pdf_text)
#      38         print(f"Answer: {answer}")
#
# <ipython-input-10-5d56e85a2eb3> in answer_question(question, context)
#      15 # Function to answer questions
#      16 def answer_question(question, context):
# ---> 17     result = qa_pipeline({"question": question, "context": context})
#      18     return result["answer"]
#      19
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     396         examples = self._args_parser(*args, **kwargs)
# ...
